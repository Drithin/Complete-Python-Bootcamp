# %%
x = False;
if x == True:
    print 'It is True'
else:
    print 'It is not'
# Out:
# It is not

# %%
x = 3

if x == 1:
    print 'It is 1'
elif x == 2:
    print 'It is 2'
else:
    print 'It is 3'
# Out:
# It is 3
