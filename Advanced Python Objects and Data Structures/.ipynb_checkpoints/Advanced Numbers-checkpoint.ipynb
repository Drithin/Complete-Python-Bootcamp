# %% [markdown]
# # Advanced Numbers

# %% [markdown]
# ### Hexadecimal

# %%
hex(123)
# Out:
# '0x7b'

# %%
hex(345)
# Out:
# '0x159'

# %% [markdown]
# ### Binary

# %%
bin(1234)
# Out:
# '0b10011010010'

# %%
bin(567)
# Out:
# '0b1000110111'

# %% [markdown]
# ### Absolute

# %%
abs(-3)
# Out:
# 3

# %%
abs(-5)
# Out:
# 5

# %% [markdown]
# ### Round

# %%
round(3.4)
# Out:
# 3.0

# %%
round(4.153)
# Out:
# 4.0

# %% [markdown]
# ### POW

# %%
pow(2,4)
# Out:
# 16

# %%
pow(3,6)
# Out:
# 729
