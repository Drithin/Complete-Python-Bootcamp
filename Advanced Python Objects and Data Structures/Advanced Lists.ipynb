# %%
l = [1,2,3]

# %%
type(l)
# Out:
# list

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.append([5,6]) #Appends Lists inside List

# %%
l
# Out:
# [1, 2, 3, 4, [5, 6]]

# %%
l.count(5)
# Out:
# 0

# %%
l.count(6)
# Out:
# 0

# %%
l.count(2)
# Out:
# 1

# %%
l.insert(2,'inserted')

# %%
l
# Out:
# [1, 2, 'inserted', 3, 4, [5, 6]]

# %%
# Puts value at the index specified

# %%
l.pop(1)
# Out:
# 2

# %%
l
# Out:
# [1, 'inserted', 3, 4, [5, 6]]

# %%
l.reverse()

# %%
l
# Out:
# [[5, 6], 4, 3, 'inserted', 1]

# %%
l.reverse()

# %%
l
# Out:
# [1, 'inserted', 3, 4, [5, 6]]

# %%
l.sort()

# %%
l
# Out:
# [1, 3, 4, [5, 6], 'inserted']
