# %%
#Addition
2+3
# Out:
# 5

# %%
#Subtraction
5-2
# Out:
# 3

# %%
#Multiplication
3*2
# Out:
# 6

# %%
#Division
7.0/2
# Out:
# 1

# %%
#Integer Value Division
8/2
# Out:
# 4

# %%
#Remainder Division
7%2
# Out:
# 1

# %%
from __future__ import division
3/2
# Out:
# 1.5

# %%
2**3
# Out:
# 8

# %%
#Value Assignment
a=5

# %%
b=6

# %%
a+b
# Out:
# 11
