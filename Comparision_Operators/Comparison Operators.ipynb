# %%
2 > 3
# Out:
# False

# %%
4 > 3
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
1 < 0
# Out:
# False

# %%
2 < 3
# Out:
# True

# %%
2 <= 2
# Out:
# True

# %%
3 <> 2
# Out:
# True

# %%
2 != 3
# Out:
# True

# %%
3 == 2
# Out:
# False

# %%
3 == 3
# Out:
# True
